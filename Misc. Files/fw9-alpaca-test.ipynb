# %% [markdown]
# # Framework 9: Alpaca Real-World Validation
# This notebook tests the Titan Oracle causal discovery engine on real stock data from Alpaca.

# %%
import pandas as pd
import numpy as np
import networkx as nx
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")

# Configuration Constants
MI_THRESHOLD = 0.05
ALPHA = 0.05
MAX_LAG = 2
N_PATHS = 1000

print("🔮 TITAN ORACLE ONLINE | Causal Physics Engine Initialized")
# Out:
# 🔮 TITAN ORACLE ONLINE | Causal Physics Engine Initialized
